# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup

# %%
# options = Options()
# options.set_headless(True)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: use setter for headless property instead of set_headless

# %%
# driver = webdriver.Chrome(chrome_options=options)
driver = webdriver.Chrome()

# %%
driver.get('https://www.bloomberg.co.jp/')

# %%
html = driver.page_source.encode('utf-8')

# %%
soup = BeautifulSoup(html, "html.parser")

# %%
print(driver.page_source)
# Out:
# <!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml" prefix="og: http://ogp.me/ns#" lang="ja"><head><script async="" src="https://ml314.com/tag.aspx?2110"></script><script src="https://www.googletagservices.com/activeview/js/current/osd.js?cb=%2Fr20100101"></script><script src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_rendering_2019111401.js"></script><script src="https://d1z2jf7jlzjs58.cloudfront.net/code/ptrack-v1.3.1-engagedtime-slots-video.js"></script><script src="https://pagead2.googlesyndication.com/pagead/show_companion_ad.js"></script><script src="https://srv-2019-11-21-00.config.parsely.com/config/bloomberg.co.jp"></script>
#                 <meta charset="utf-8" />
#                 <link href="//assets.bwbx.io" rel="preconnect" crossorigin="" />
#         <link href="//px.moatads.com" rel="preconnect" crossorigin="" />
#         <link href="//ml314.com" rel="preconnect" crossorigin="" />
#         <link href="//www.googletagmanager.com" rel="preconnect" crossorigin="" />
#         <link href="//www.google-analytics.com" rel="preconnect" crossorigin="" />
#         <link href="//location.bloomberg.com" rel="preconnect" crossorigin="" />
#         <link href="//login.bloomberg.com" rel="preconnect" crossorigin="" />
#                 <link href="https://assets.bwbx.io/s3/fontservice/fonts/BWHaasGrotesk-55Roman-Web-5cf5733cd9.woff2" type="font/woff2" rel="preload" as="font" crossorigin="" />
# <link href="https://assets.bwbx.io/s3/fontservice/fonts/BWHaasGrotesk-75Bold-Web-de8c77cce2.woff2" type="font/woff2" rel="preload" as="font" crossorigin="" />
# <link href="https://assets.bwbx.io/s3/fontservice/fonts/BWHaasGrotesk-95Black-Web-3629d1569b.woff2" type="font/woff2" rel="preload" as="font" crossorigin="" />
# <link href="https://assets.bwbx.io/s3/fontservice/fonts/PublicoHeadline-Black-Web-01df76cd27.woff2" type="font/woff2" rel="preload" as="font" crossorigin="" />
# <link href="https://assets.bwbx.io/s3/fontservice/fonts/PublicoHeadline-Bold-Web-e816328678.woff2" type="font/woff2" rel="preload" as="font" crossorigin="" />
# <link href="https://assets.bwbx.io/s3/fontservice/fonts/PublicoText-Bold-Web-3c5266a48e.woff2" type="font/woff2" rel="preload" as="font" crossorigin="" />
# <link href="https://assets.bwbx.io/s3/fontservice/fonts/PublicoText-Roman-Web-bfa063ee27.woff2" type="font/woff2" rel="preload" as="font" crossorigin="" />
# <link href="https://assets.bwbx.io/s3/fontservice/fonts/TiemposTextWeb-Regular-0c712f870b.woff2" type="font/woff2" rel="preload" as="font" crossorigin="" />
#                 <meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover" />
#         <meta name="apple-mobile-web-app-capable" content="no" />
#         <meta name="apple-mobile-web-app-status-bar-style" content="black" />
#         <meta name="apple-itunes-app" content="app-id=281941097, affiliate-data=ct=smartbanner_mobileweb&amp;pt=8949&amp;utm_source=smart_banner" />
#                 <script async="" src="//cdn.taboola.com/libtrc/unip/1194877/tfa.js" id="tb_tfa_script"></script><script type="text/javascript" async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js"></script><script src="//bat.bing.com/bat.js" async=""></script><script type="text/javascript" async="" src="//www.googleadservices.com/pagead/conversion_async.js"></script><script type="text/javascript" async="" src="//www.googleadservices.com/pagead/conversion_async.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script defer="" src="https://www.googletagmanager.com/gtm.js?id=GTM-MNTH5N"></script><script>
#             (function(w, d, n) {
#                 w[n] = w[n] || [];
#                 [["trackClick", "click"], ["trackImpression", "impression"]].forEach(function(m) {
#                     w[n][m[0]] = w[n][m[0]] || function(d) {
#                         this.push(Object.assign(d, { eventType: m[1] }));
#                     };
#                 });
#             })(window, document, "bbeep");
#         </script>
#                 <title>Bloomberg.co.jp</title><link rel="canonical" href="https://www.bloomberg.co.jp/" /><meta name="description" content="世界の最新金融ニュース、マーケット情報、市場の分析や、マーケットデータ、金融情報をご提供しています。株式、投資信託から、世界各国の株価指数、金利/債券、商品先物など最新のマーケット情報を掲載。ブルームバーグ" /><meta name="homepage" content="true" /><meta name="referrer" content="unsafe-url" /><meta name="referrer" content="always" /><meta property="og:site_name" content="Bloomberg.com" /><meta property="og:type" content="website" /><meta property="og:description" content="世界の最新金融ニュース、マーケット情報、市場の分析や、マーケットデータ、金融情報をご提供しています。株式、投資信託から、世界各国の株価指数、金利/債券、商品先物など最新のマーケット情報を掲載。ブルームバーグ" /><meta property="og:title" content="Bloomberg.co.jp" /><meta property="og:url" content="https://www.bloomberg.co.jp/" /><meta name="twitter:card" content="summary_large_image" /><meta name="twitter:site" content="@business" /><meta name="twitter:description" content="世界の最新金融ニュース、マーケット情報、市場の分析や、マーケットデータ、金融情報をご提供しています。株式、投資信託から、世界各国の株価指数、金利/債券、商品先物など最新のマーケット情報を掲載。ブルームバーグ" /><meta name="twitter:title" content="Bloomberg.co.jp" /><meta name="parsely-title" content="Bloomberg.co.jp" /><meta name="parsely-link" content="https://www.bloomberg.co.jp/" /><meta name="parsely-type" content="sectionpage" /><link rel="icon" type="image/png" href="https://assets.bwbx.io/s3/javelin/public/hub/images/favicon-black-63fe5249d3.png" /><link rel="apple-touch-icon" sizes="57x57" href="https://assets.bwbx.io/s3/javelin/public/hub/images/apple-touch-icon-57x57-b572ef8093.png" /><link rel="apple-touch-icon" sizes="60x60" href="https://assets.bwbx.io/s3/javelin/public/hub/images/apple-touch-icon-60x60-b0d19bb405.png" /><link rel="apple-touch-icon" sizes="72x72" href="https://assets.bwbx.io/s3/javelin/public/hub/images/apple-touch-icon-72x72-a5bfb2afba.png" /><link rel="apple-touch-icon" sizes="76x76" href="https://assets.bwbx.io/s3/javelin/public/hub/images/apple-touch-icon-76x76-6ed14bcfc8.png" /><link rel="apple-touch-icon" sizes="114x114" href="https://assets.bwbx.io/s3/javelin/public/hub/images/apple-touch-icon-114x114-b5fb8b8c07.png" /><link rel="apple-touch-icon" sizes="120x120" href="https://assets.bwbx.io/s3/javelin/public/hub/images/apple-touch-icon-120x120-ef3226f2bd.png" /><link rel="apple-touch-icon" sizes="144x144" href="https://assets.bwbx.io/s3/javelin/public/hub/images/apple-touch-icon-144x144-3c26d576a9.png" /><link rel="apple-touch-icon" sizes="152x152" href="https://assets.bwbx.io/s3/javelin/public/hub/images/apple-touch-icon-152x152-5ccd0ec96e.png" /><link rel="apple-touch-icon" sizes="180x180" href="https://assets.bwbx.io/s3/javelin/public/hub/images/apple-touch-icon-180x180-c1a237984e.png" />
#                 <style>@font-face {
# font-family: 'BWHaasGrotesk-55Roman-Web';
# font-display: fallback;
# src: url('https://assets.bwbx.io/s3/fontservice/fonts/BWHaasGrotesk-55Roman-Web-7998fbcba8.eot');
# src: local('?'),
# url('https://assets.bwbx.io/s3/fontservice/fonts/BWHaasGrotesk-55Roman-Web-5cf5733cd9.woff2') format('woff2'),
# url('https://assets.bwbx.io/s3/fontservice/fonts/BWHaasGrotesk-55Roman-Web-a1ea4fd367.woff') format('woff');
# }
# @font-face {
# font-family: 'BWHaasGrotesk-75Bold-Web';
# font-display: fallback;
# src: url('https://assets.bwbx.io/s3/fontservice/fonts/BWHaasGrotesk-75Bold-Web-de8c77cce2.woff2') format('woff2'),
# url('https://assets.bwbx.io/s3/fontservice/fonts/BWHaasGrotesk-75Bold-Web-506363704e.woff') format('woff');
# }
# @font-face {
# font-family: 'BWHaasGrotesk-95Black-Web';
# font-display: fallback;
# src: url('https://assets.bwbx.io/s3/fontservice/fonts/BWHaasGrotesk-95Black-Web-3629d1569b.woff2') format('woff2'),
# url('https://assets.bwbx.io/s3/fontservice/fonts/BWHaasGrotesk-95Black-Web-37847ad026.woff') format('woff');
# }
# @font-face {
# font-family: 'PublicoHeadline-Black-Web';
# font-display: swap;
# src: url('https://assets.bwbx.io/s3/fontservice/fonts/PublicoHeadline-Black-Web-d1a1b3d673.eot');
# src: local('?'),
# url('https://assets.bwbx.io/s3/fontservice/fonts/PublicoHeadline-Black-Web-01df76cd27.woff2') format('woff2'),
# url('https://assets.bwbx.io/s3/fontservice/fonts/PublicoHeadline-Black-Web-4e5abb92d5.woff') format('woff');
# }
# @font-face {
# font-family: 'PublicoHeadline-Bold-Web';
# font-display: swap;
# src: url('https://assets.bwbx.io/s3/fontservice/fonts/PublicoHeadline-Bold-Web-cec3a90fbb.eot');
# src: local('?'),
# url('https://assets.bwbx.io/s3/fontservice/fonts/PublicoHeadline-Bold-Web-e816328678.woff2') format('woff2'),
# url('https://assets.bwbx.io/s3/fontservice/fonts/PublicoHeadline-Bold-Web-45a1792556.woff') format('woff');
# }
# @font-face {
# font-family: 'PublicoText-Bold-Web';
# font-display: swap;
# src: url('https://assets.bwbx.io/s3/fontservice/fonts/PublicoText-Bold-Web-3c5266a48e.woff2') format('woff2'),
# url('https://assets.bwbx.io/s3/fontservice/fonts/PublicoText-Bold-Web-8851dd6a6e.woff') format('woff');
# }
# @font-face {
# font-family: 'PublicoText-Roman-Web';
# font-display: swap;
# src: url('https://assets.bwbx.io/s3/fontservice/fonts/PublicoText-Roman-Web-bfa063ee27.woff2') format('woff2'),
# url('https://assets.bwbx.io/s3/fontservice/fonts/PublicoText-Roman-Web-e953eb7239.woff') format('woff');
# }
# @font-face {
# font-family: 'TiemposTextWeb-Regular';
# font-display: swap;
# src: url('https://assets.bwbx.io/s3/fontservice/fonts/TiemposTextWeb-Regular-d1a13989fe.eot');
# src: local('?'),
# url('https://assets.bwbx.io/s3/fontservice/fonts/TiemposTextWeb-Regular-0c712f870b.woff2') format('woff2'),
# url('https://assets.bwbx.io/s3/fontservice/fonts/TiemposTextWeb-Regular-ce6578caa5.woff') format('woff'),
# url('https://assets.bwbx.io/s3/fontservice/fonts/TiemposTextWeb-Regular-564ae670c4.svg') format('svg');
# }</style>
#                 <link href="https://assets.bwbx.io/font-service/css/AvenirNextPForBBG:400,600/styled-font-face.css" media="all" property="stylesheet" rel="stylesheet" type="text/css" /><link href="https://www.bloomberg.com/tophat/assets/v2.4.0/that.css" media="all" property="stylesheet" rel="stylesheet" type="text/css" />
#                 <link href="https://assets.bwbx.io/font-service/css/Bloomberg,BWHaasText-55Roman,BWHaasHead-75Bold,BWHaasHead-95Black,AvenirNext-Demi/font-face.css" media="all" property="stylesheet" rel="stylesheet" type="text/css" /><link href="https://assets.bwbx.io/s3/bbnav/public/stylesheets/bb-cojp-nav-9d702098a4.css" media="all" property="stylesheet" rel="stylesheet" type="text/css" />
#                 <link href="https://assets.bwbx.io/font-service/css/Bloomberg/font-face.css" media="all" property="stylesheet" rel="stylesheet" type="text/css" /><link href="https://assets.bwbx.io/s3/bbnav/public/stylesheets/bb-cojp-footer-652e8b7bf2.css" media="all" property="stylesheet" rel="stylesheet" type="text/css" />
#                 <style media="all" type="text/css">.bb-nav&gt;h1{font-size:1em}.bb-nav-placeholder{height:4rem}.bb-nav-root{z-index:3}.bb-mini-player{z-index:3}.skiplink__hide-until-focus{position:absolute;clip:rect(1px 1px 1px 1px);clip:rect(1px,1px,1px,1px);padding:0;border:0;height:1px;width:1px;overflow:hidden;white-space:nowrap;left:5px;top:5px}.skiplink__hide-until-focus:active,.skiplink__hide-until-focus:focus{font-family:BWHaasGrotesk-55Roman-Web,Helvetica,Arial,sans-serif;font-size:14px;overflow:visible;height:auto;width:auto;clip:auto;z-index:3;background-color:#000;color:#fff;padding:5px;outline-offset:-3px;outline-color:#767676}.skiplink__hide-until-focus:active:lang(ja),.skiplink__hide-until-focus:focus:lang(ja){font-family:"Hiragino Kaku Gothic Pro",Meiryo,"MS Pgothic",Helvetica,Arial,Verdana,sans-serif}.leaderboard-container{position:relative;margin:auto;z-index:1;background-color:#f3f4ef}.leaderboard-container .queued-ad[data-position=leaderboard]{width:100%;text-align:center;background-color:#f3f4ef;margin-bottom:0;font-size:0}.leaderboard-container .queued-ad[data-position=leaderboard] .bb-ads__rendered{display:block}.leaderboard-container .queued-ad[data-position=leaderboard] .bb-ads__ad:not(.bb-ads__rendered){height:0}.leaderboard-container .queued-ad[data-position=leaderboard] .bb-ads__empty{display:none}.leaderboard-container .bb-ads__empty~.leaderboard-ad-dummy{height:0}.leaderboard-container[data-state=pinned]{z-index:3}.leaderboard-container[data-state=pinned] .queued-ad[data-position=leaderboard]{position:fixed}/*! normalize.css v4.1.1 | MIT License | github.com/necolas/normalize.css */html{font-family:sans-serif;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}body{margin:0}article,aside,details,figcaption,figure,footer,header,main,menu,nav,section,summary{display:block}audio,canvas,progress,video{display:inline-block}audio:not([controls]){display:none;height:0}progress{vertical-align:baseline}[hidden],template{display:none}a{background-color:transparent;-webkit-text-decoration-skip:objects}a:active,a:hover{outline-width:0}abbr[title]{border-bottom:none;text-decoration:underline;text-decoration:underline dotted}b,strong{font-weight:inherit}b,strong{font-weight:bolder}dfn{font-style:italic}h1{font-size:2em;margin:.67em 0}mark{background-color:#fbe548;color:#000}small{font-size:80%}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sub{bottom:-.25em}sup{top:-.5em}img{border-style:none}svg:not(:root){overflow:hidden}code,kbd,pre,samp{font-family:monospace,monospace;font-size:1em}figure{margin:1em 40px}hr{box-sizing:content-box;height:0;overflow:visible}button,input,select,textarea{font:inherit;margin:0}optgroup{font-weight:700}button,input{overflow:visible}button,select{text-transform:none}[type=reset],[type=submit],button,html [type=button]{-webkit-appearance:button}[type=button]::-moz-focus-inner,[type=reset]::-moz-focus-inner,[type=submit]::-moz-focus-inner,button::-moz-focus-inner{border-style:none;padding:0}[type=button]:-moz-focusring,[type=reset]:-moz-focusring,[type=submit]:-moz-focusring,button:-moz-focusring{outline:1px dotted ButtonText}fieldset{border:1px solid #ddd;margin:0 2px;padding:.35em .625em .75em}legend{box-sizing:border-box;color:inherit;display:table;max-width:100%;padding:0;white-space:normal}textarea{overflow:auto}[type=checkbox],[type=radio]{box-sizing:border-box;padding:0}[type=number]::-webkit-inner-spin-button,[type=number]::-webkit-outer-spin-button{height:auto}[type=search]{-webkit-appearance:textfield;outline-offset:-2px}[type=search]::-webkit-search-cancel-button,[type=search]::-webkit-search-decoration{-webkit-appearance:none}::-webkit-input-placeholder{color:inherit;opacity:.54}::-webkit-file-upload-button{-webkit-appearance:button;font:inherit}a,abbr,acronym,address,applet,article,aside,audio,b,big,blockquote,body,canvas,caption,center,cite,code,dd,del,details,dfn,div,dl,dt,em,embed,fieldset,figcaption,figure,footer,form,h1,h2,h3,h4,h ...
# <style media="(min-width:761px)" type="text/css">.leaderboard-container{font-size:0}.leaderboard-container .leaderboard-ad-dummy{height:90px}.leaderboard-container .bb-ads__rendered~.leaderboard-ad-dummy{display:none}</style>
# <style media="(min-width:1021px)" type="text/css">.breaking-news-placeholder{transform:translateY(-70px);height:70px}.breaking-news-placeholder.empty{height:0}.hub-main{transform:translateY(-70px)}.hub-main.no-breaking{transform:none}.hub-main{width:100%;padding-top:20px;padding-bottom:50px}.hub-main .hub-zone-full,.hub-main .hub-zone-full__content{width:100%}.hub-main .hub-zone-full&gt;section,.hub-main .hub-zone-full__content&gt;section{margin-left:auto;margin-right:auto}.hub-main .hub-zone-lefty__left-rail,.hub-main .hub-zone-lefty__rail{vertical-align:top;display:inline-block;width:140px;margin-right:50px}.hub-main .hub-zone-lefty__left-rail&gt;div:last-child,.hub-main .hub-zone-lefty__left-rail&gt;section:last-child,.hub-main .hub-zone-lefty__rail&gt;div:last-child,.hub-main .hub-zone-lefty__rail&gt;section:last-child{margin-bottom:0}.hub-main .hub-zone-righty__rail,.hub-main .hub-zone-righty__right-rail{vertical-align:top;display:inline-block;width:300px}.hub-main .hub-zone-righty__rail&gt;div:last-child,.hub-main .hub-zone-righty__rail&gt;section:last-child,.hub-main .hub-zone-righty__right-rail&gt;div:last-child,.hub-main .hub-zone-righty__right-rail&gt;section:last-child{margin-bottom:0}.hub-main .hub-zone-lefty__content{vertical-align:top;display:inline-block}.hub-main .hub-zone-lefty__content&gt;div:last-child,.hub-main .hub-zone-lefty__content&gt;section:last-child{margin-bottom:0}.hub-main .hub-zone-righty__content{vertical-align:top;display:inline-block;margin-right:20px}.hub-main .hub-zone-righty__content&gt;div:last-child,.hub-main .hub-zone-righty__content&gt;section:last-child{margin-bottom:0}.hub-main .hub-zone-switch__content{vertical-align:top;display:inline-block;margin-right:20px}.hub-main .hub-zone-switch__content&gt;div:last-child,.hub-main .hub-zone-switch__content&gt;section:last-child{margin-bottom:0}.hub-main .hub-zone-switch__left-rail{vertical-align:top;display:inline-block;width:140px;margin-right:50px}.hub-main .hub-zone-switch__left-rail&gt;div:last-child,.hub-main .hub-zone-switch__left-rail&gt;section:last-child{margin-bottom:0}.hub-main .hub-zone-switch__right-rail{vertical-align:top;display:inline-block;width:300px}.hub-main .hub-zone-switch__right-rail&gt;div:last-child,.hub-main .hub-zone-switch__right-rail&gt;section:last-child{margin-bottom:0}.embed-module{margin-bottom:20px}.embed-module article,.embed-module div,.embed-module section{box-sizing:border-box}@media (max-width:760px){.embed-module{margin-bottom:20px}}.embed-module__title{font-family:BWHaasGrotesk-75Bold-Web,Helvetica,Arial,sans-serif}.embed-module__title:lang(ja){font-family:"Hiragino Kaku Gothic Pro",Meiryo,"MS Pgothic",Helvetica,Arial,Verdana,sans-serif}.embed-module .thirdparty-embed{overflow:hidden;text-align:center;width:100%;height:100%}.embed-module .thirdparty-embed .inline-media{float:none;text-align:left;margin-left:auto;margin-right:auto}.embed-module .thirdparty-embed__container{display:inline-block;position:relative;width:100%;height:100%}.embed-module .thirdparty-embed__iframe{position:absolute;width:100%;height:100%;top:0;left:0}.embed-module .thirdparty-embed iframe{clear:both;margin-left:auto;margin-right:auto;border:0 none}.embed-module .thirdparty-embed iframe{width:100%}.embed-module__button-text{display:block;border:1px solid;color:#000;text-decoration:none;padding:12px 10px;font-family:BWHaasGrotesk-75Bold-Web,Helvetica,Arial,sans-serif;font-size:12px;text-align:center;max-width:140px;margin:10px auto 0;user-select:none;transition:color .2s ease-out}.embed-module__button-text:lang(ja){font-family:"Hiragino Kaku Gothic Pro",Meiryo,"MS Pgothic",Helvetica,Arial,Verdana,sans-serif}.embed-module__button-text:hover{color:#767676}.hub-main[data-theme=dark] .embed-module__title{color:#fff}.hub-main[data-theme=dark] .embed-module__button-text{color:#fff;border-color:#fff}.hub-main[data-theme=dark] .embed-module__button-text:hover{color:#ccc;border-color:#ccc}.embed-module__title{margin-bottom:10px;font-size: ...
# <style media="(min-width:1021px) and (max-width:1280px)" type="text/css">.hub-main{width:100%;padding-top:20px;padding-bottom:50px}.hub-main .hub-zone-full,.hub-main .hub-zone-full__content{width:100%}.hub-main .hub-zone-full&gt;section,.hub-main .hub-zone-full__content&gt;section{margin-left:auto;margin-right:auto}.hub-main .hub-zone-lefty{width:980px;margin:0 auto 30px}.hub-main .hub-zone-righty{width:980px;margin:0 auto 30px}.hub-main .hub-zone-switch{width:980px;margin:0 auto 30px}.hub-main .hub-zone-lefty__content{width:790px}.hub-main .hub-zone-righty__content{width:660px}.hub-main .hub-zone-switch__content{width:470px}</style>
# <style media="(min-width:1281px)" type="text/css">.hub-main{width:100%;padding-top:20px;padding-bottom:50px}.hub-main .hub-zone-full,.hub-main .hub-zone-full__content{width:100%}.hub-main .hub-zone-full&gt;section,.hub-main .hub-zone-full__content&gt;section{margin-left:auto;margin-right:auto}.hub-main .hub-zone-lefty{width:1160px;margin:0 auto 30px}.hub-main .hub-zone-righty{width:1160px;margin:0 auto 30px}.hub-main .hub-zone-switch{width:1160px;margin:0 auto 30px}.hub-main .hub-zone-lefty__content{width:970px}.hub-main .hub-zone-righty__content{width:840px}.hub-main .hub-zone-switch__content{width:650px}</style>
# <style media="(min-width:761px) and (max-width:1020px)" type="text/css">.hub-main{width:100%;padding-top:20px;padding-bottom:50px}.hub-main .hub-zone-full,.hub-main .hub-zone-full__content{width:100%}.hub-main .hub-zone-full&gt;section,.hub-main .hub-zone-full__content&gt;section{margin-left:auto;margin-right:auto}.hub-main .hub-zone-lefty{width:680px;margin:0 auto}.hub-main .hub-zone-righty{width:680px;margin:0 auto}.hub-main .hub-zone-switch{width:680px;margin:0 auto}.hub-main .hub-zone-lefty__left-rail,.hub-main .hub-zone-lefty__rail,.hub-main .hub-zone-righty__rail,.hub-main .hub-zone-righty__right-rail,.hub-main .hub-zone-switch__left-rail,.hub-main .hub-zone-switch__right-rail{display:none}.hub-main .hub-zone-full,.hub-main .hub-zone-lefty__content,.hub-main .hub-zone-righty__content,.hub-main .hub-zone-switch__content{display:block;width:100%}</style>
# <style media="(max-width:760px)" type="text/css">.hub-main{width:100%;padding-top:20px;padding-bottom:50px;padding-top:30px;padding-bottom:30px}.hub-main .hub-zone-full,.hub-main .hub-zone-full__content{width:100%}.hub-main .hub-zone-full&gt;section,.hub-main .hub-zone-full__content&gt;section{margin-left:auto;margin-right:auto}.hub-main .hub-zone-lefty__left-rail,.hub-main .hub-zone-lefty__rail,.hub-main .hub-zone-righty__rail,.hub-main .hub-zone-righty__right-rail,.hub-main .hub-zone-switch__left-rail,.hub-main .hub-zone-switch__right-rail{display:none}</style>
# <style media="(max-width:1020px)" type="text/css">.social-buttons-module{display:none}</style>
#                 <script type="text/javascript">
#             (function(w) {
#                 var data = {"adcode":"japan/home","contentType":"homepage-cojpv2","pageType":"homepage","parselySite":"bloomberg.co.jp","vertical":"business","brand":"business","title":"Bloomberg.co.jp","transporter":"false","refresh":"false"};
#                 if (/(^|(; ))is-auto-refresh=Y($|;)/.test(document.cookie)) {
#                     data.refresh = "true";
#                     document.cookie = "is-auto-refresh=;domain=" + window.location.hostname + ";path=/;expires=" + (new Date()).toUTCString();
#                 }
#                 w.dataLayer = w.dataLayer || [];
#                 w.dataLayer.push(data);
#             })(window);
#         </script>
#                 <!-- Google Tag Manager --><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&amp;l='+l:'';j.defer=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-MNTH5N');</script><!-- End Google Tag Manager -->
#
#             <script async="" src="https://www.bloomberg.com/tophat/assets/v2.4.0/that.js" type="text/javascript"></script><script async="" src="https://assets.bwbx.io/s3/bbnav/public/javascripts/cojp/bb-cojp-nav-18e2cfef4e.js" type="text/javascript"></script><script src="https://www.googleadservices.com/pagead/conversion/1063184170/?random=1574296903636&amp;cv=9&amp;fst=1574296903636&amp;num=1&amp;value=0&amp;label=6VpQCOnp7YkBEKrO-_oD&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=1080&amp;u_w=1920&amp;u_ah=1040&amp;u_aw=1920&amp;u_cd=24&amp;u_his=2&amp;u_tz=540&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2wgav9&amp;sendb=1&amp;ig=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.bloomberg.co.jp%2F&amp;tiba=Bloomberg.co.jp&amp;hn=www.googleadservices.com&amp;bttype=purchase&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><script src="https://www.googleadservices.com/pagead/conversion/759744127/?random=1574296903641&amp;cv=9&amp;fst=1574296903641&amp;num=1&amp;value=0&amp;label=NPt6CL6b_JYBEP-Mo-oC&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=1080&amp;u_w=1920&amp;u_ah=1040&amp;u_aw=1920&amp;u_cd=24&amp;u_his=2&amp;u_tz=540&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2wgav9&amp;sendb=1&amp;ig=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.bloomberg.co.jp%2F&amp;tiba=Bloomberg.co.jp&amp;hn=www.googleadservices.com&amp;bttype=purchase&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/759744127/?random=1574296903644&amp;cv=9&amp;fst=1574296903644&amp;num=1&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=1080&amp;u_w=1920&amp;u_ah=1040&amp;u_aw=1920&amp;u_cd=24&amp;u_his=2&amp;u_tz=540&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2wgav9&amp;sendb=1&amp;ig=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.bloomberg.co.jp%2F&amp;tiba=Bloomberg.co.jp&amp;hn=www.googleadservices.com&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><link rel="preload" href="https://adservice.google.co.jp/adsid/integrator.js?domain=www.bloomberg.co.jp" as="script" /><script type="text/javascript" src="https://adservice.google.co.jp/adsid/integrator.js?domain=www.bloomberg.co.jp"></script><link rel="preload" href="https://adservice.google.com/adsid/integrator.js?domain=www.bloomberg.co.jp" as="script" /><script type="text/javascript" src="https://adservice.google.com/adsid/integrator.js?domain=www.bloomberg.co.jp"></script><script src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_2019111401.js" async=""></script><link rel="prefetch" href="https://tpc.googlesyndication.com/safeframe/1-0-36/html/container.html" /></head>
#             <body>
#                 <!-- Google Tag Manager (noscript) --><noscript>&lt;iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MNTH5N" height="0" width="0" style="display:none;visibility:hidden"&gt;&lt;/iframe&gt;</noscript><!-- End Google Tag Manager (noscript) -->
#                 <a href="#skip-to-main-content" class="skiplink__hide-until-focus">コンテンツにスキップする</a>
#
#                 <script type="text/javascript">window.__bloomberg__=window.__bloomberg__||{};window.__bloomberg__.environment={"playlistPlayerEnabled":true,"psznTrackingUrl":"https://tracking.bloomberg.com/images/tracking-pixel.gif","psznRecommendationUrl":"https://personalization.bloomberg.com","registrationUrl":"https://login.bloomberg.com","tickerToutEnabled":true,"tickerToutUrl":"https://www.bloomberg.com/markets/modules/datastrip?version=2","videoPlayerUrl":"https://cdn.gotraffic.net/projector/latest/bplayer.js","__fnEnabled":true,"__pvcEnabled":true,"greenEnabled":false};</script>
#                 <script type="text/javascript">window.__bloomberg__.abba=[{"targetId":"tllfj","priority":-1,"condition":"{\"or\":[{\"and\":[{\"value\":\"opera\",\"comparator\":\"eq\",\"id\":\"userAgent\",\"type\":\"string\",\"store\":\"userAgent\"},{\"value\":\"desktop\",\"comparator\":\"eq\",\"id\":\"device\",\"type\":\"string\",\"store\":\"device\"}]},{\"and\":[{\"value\":\"desktop\",\"comparator\":\"eq\",\"id\":\"device\",\"type\":\"string\",\"store\":\"device\"},{\"value\":\"chrome\",\"comparator\":\"eq\",\"id\":\"userAgent\",\"type\":\"string\",\"store\":\"userAgent\"}]},{\"and\":[{\"value\":\"desktop\",\"comparator\":\"eq\",\"id\":\"device\",\"type\":\"string\",\"store\":\"device\"},{\"value\":\"firefox\",\"comparator\":\"eq\",\"id\":\"userAgent\",\"type\":\"string\",\"store\":\"userAgent\"}]}]}","config":"{\"webpushprompt\":{\"title\":\"Get breaking news from Bloomberg. \",\"titleBold\":\"Turn on desktop notifications.\",\"variation\":\"wide\",\"turnonText\":\"Turn on\",\"nothanksText\":\"No thanks\",\"shouldDisplay\":false,\"deferMinAfterClose\":1440,\"showAfterPageViews\":2,\"deferMinAfterIgnore\":60}}","experiments":[]},{"targetId":"t8m8w","priority":-1,"condition":"{\"and\":[{\"or\":[{\"value\":\"US\",\"comparator\":\"not\",\"id\":\"geoIp\",\"type\":\"string\",\"store\":\"geo\"},{\"value\":\"US\",\"comparator\":\"eq\",\"id\":\"geoIp\",\"type\":\"string\",\"store\":\"geo\"}]}]}","config":"{}","experiments":[]}];</script>
#                 <script type="text/javascript">
#             (function () {
#                 if(typeof window.CustomEvent === "function") return false;
#                 function CustomEvent(event, p) {
#                     p = p || {bubbles: false, cancelable: false, detail: undefined};
#                     var e = document.createEvent("CustomEvent");
#                     e.initCustomEvent(event, p.bubbles, p.cancelable, p.detail);
#                     return e;
#                 }
#                 CustomEvent.prototype = window.Event.prototype;
#                 window.CustomEvent = CustomEvent;
#             })();
#         </script>
#                 <script type="text/javascript">
#             window.__bloomberg__.ads = {};
#             window.__bloomberg__.ads.queue = [];
#
#             window.__bloomberg__.ads.enqueue = function(id) {
#                 if (window.__bloomberg__.ads.render) {
#                     return window.__bloomberg__.ads.render(id);
#                 }
#                 window.__bloomberg__.ads.queue.push(id);
#             };
#         </script>
#                 <script id="page-level-ad-config-cojp-v2" type="application/json">{"adCode":"japan/home","targeting":{"page":"cojp-v2"}}</script>
#
#                 <div class="leaderboard-container" style="">
#         <div id="leaderboard-cojp-v2" class="queued-ad" data-position="leaderboard" tabindex="-1" role="presentation" data-ad-status="rendered"><div class="bb-ads__rendered bb-ads__ad bb-ads__no_size bb-ads__size_1x1" id="d9c28cd65f0cf3244180538464d73c70" data-google-query-id="CIyNlPuI-uUCFUtqvQodptkNPQ"><div id="google_ads_iframe_/5262/japan/home_0__container__" style="border: 0pt none;"><iframe id="google_ads_iframe_/5262/japan/home_0" title="3rd party ad content" name="google_ads_iframe_/5262/japan/home_0" width="728" height="90" scrolling="no" marginwidth="0" marginheight="0" frameborder="0" srcdoc="" style="border: 0px; vertical-align: bottom;" data-google-container-id="1" data-integralas-id-7f8216e3-bcca-c4fc-31ff-e21d26aaf1e8="" data-load-complete="true"></iframe></div></div>
#             <script type="text/javascript">
#                 window.__bloomberg__.ads.enqueue("leaderboard-cojp-v2");
#             </script>
#             <script class="params" type="application/json">{"pageId":"cojp-v2","position":"leaderboard","dimensions":{"large_desktop":[[728,90],[970,250],[5,16],[1,1]],"small_desktop":[[728,90],[970,250],[5,16],[1,1]],"tablet":[[728,90],[5,16],[1,1]],"mobile":[[320,50],[5,16],[1,1]]},"strategy":"viewable","type":"Top Horizontal Ad","targeting":{"position":"leaderboard","page":"cojp-v2","url":"/"},"containerId":"leaderboard-cojp-v2"}</script>
#             <div class="leaderboard-ad-dummy"></div>
#         </div>
#     </div>
#                 <style>#bb-that a{text-decoration:none}#bb-that .bb-that__sitemap{overflow:hidden;position:relative;max-height:0;visibility:hidden;-webkit-transition:max-height 0.6s ease-in-out,visibility 0.6s ease-in-out;-o-transition:max-height 0.6s ease-in-out,visibility 0.6s ease-in-out;transition:max-height 0.6s ease-in-out,visibility 0.6s ease-in-out}#bb-that{font-family:AvenirNextPForBBG,"Helvetica Neue",Helvetica,Arial,sans-serif;background:#000;position:relative}@media (max-width: 759px){#bb-that .bb-that{display:none}}#bb-that *{font-family:AvenirNextPForBBG,"Helvetica Neue",Helvetica,Arial,sans-serif !important}#bb-that .bb-that--container{margin:0 auto;padding:0 30px;box-sizing:content-box}@media (min-width: 1020px){#bb-that .bb-that--container{padding:0}}#bb-that .bb-that--container:before,#bb-that .bb-that--container:after{content:" ";display:table}#bb-that .bb-that--container:after{clear:both}@media (min-width: 760px){#bb-that .bb-that--container{width:680px}}@media (min-width: 1020px){#bb-that .bb-that--container{width:980px}}@media (min-width: 1280px){#bb-that .bb-that--container{width:1160px}}#bb-that .bb-that-header{font-weight:600;font-size:15px;line-height:30px;padding:15px}@media (min-width: 760px){#bb-that .bb-that-header{font-size:12px;height:30px;padding:0}}#bb-that .bb-that-header__link{position:relative;display:block;outline-offset:2px}@media (min-width: 760px){#bb-that .bb-that-header__link{display:inline-block;padding:0 12px}}#bb-that .bb-that-header__link,#bb-that .bb-that-header__link&gt;span{color:#f3f4ef;font-family:inherit;font-size:inherit;line-height:inherit}@media (min-width: 760px){#bb-that .bb-that-header__link,#bb-that .bb-that-header__link&gt;span{line-height:1;-webkit-font-smoothing:subpixel-antialiased;-moz-osx-font-smoothing:auto}}#bb-that .bb-that-header__link:first-child{padding-left:0}#bb-that .bb-that-header__link:after{font-size:9px;position:absolute}@media (min-width: 760px){#bb-that .bb-that-header__link+.bb-that-header__link{border-left:1px solid #b3b3b3}#bb-that .bb-that-header__link+.bb-that-header__link:after{top:-3px}}#bb-that .bb-that-header__link&gt;span:first-of-type{display:inline}#bb-that .bb-that-header__link&gt;span:first-of-type+span{display:none}@media (max-width: 1019px){#bb-that .bb-that-header__link&gt;span:first-of-type{display:none}#bb-that .bb-that-header__link&gt;span:first-of-type+span{display:inline}}#bb-that .bb-that-header--sitemap-trigger{padding:0 27px 0 12px}#bb-that .bb-that-header--sitemap-trigger:after{display:inline-block;content:url("data:image/svg+xml,%3Csvg%20xmlns%3D%27http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg%27%20viewBox%3D%270%200%2015%2015%27%3E%3Cpath%20d%3D%27M0,2.5l7.5,10l7.5-10H0z%27%20fill%3D%27%23fff%27%2F%3E%3C%2Fsvg%3E");height:9px;width:9px;line-height:initial;opacity:0.7;-webkit-transition:opacity 0.1s ease-out;-o-transition:opacity 0.1s ease-out;transition:opacity 0.1s ease-out}#bb-that .bb-that-header--sitemap-trigger:hover:after{opacity:1}#bb-that .bb-that-header--sitemap-trigger:after{height:9px;width:9px;-webkit-transform:rotate(0);-ms-transform:rotate(0);-o-transform:rotate(0);transform:rotate(0);-webkit-transition:transform 0.35s ease;-o-transition:transform 0.35s ease;transition:transform 0.35s ease}@media (min-width: 760px){#bb-that .bb-that-header--sitemap-trigger:after{right:12px;top:2px;line-height:1}}@media (min-width: 1020px){#bb-that .bb-that--open{border-bottom:1px solid #474747}}#bb-that .bb-that--open .bb-that-header--sitemap-trigger:after{-webkit-transform:rotate(180deg);-ms-transform:rotate(180deg);-o-transform:rotate(180deg);transform:rotate(180deg)}
# </style>
# <div id="bb-that" data-alert-service="https://www.bloomberg.com/tophat/api/alerts?site=bcom">
# 	<nav class="bb-that">
# 		<a href="#that-jump-content" class="bb-that__skip-to-content" aria-label="Skip to content" role="button" tabindex="-1">Skip to content</a>
#     <div class="bb-that-header bb-that--container">
#         <a class="bb-that-header__link bb-that-header--sitemap-trigger" href="http://www.bloomberg.com/company/?utm_source=bloomberg-menu&amp;utm_medium=bcom" role="button" aria-controls="bb-that--container" aria-expanded="false">Bloomberg the Company &amp; Its Products</a><a class="bb-that-header__link" href="https://bba.bloomberg.net/?utm_source=bloomberg-menu&amp;utm_medium=bcom"><span>Bloomberg Anywhere Remote Login</span><span>Bloomberg Anywhere Login</span></a><a class="bb-that-header__link" href="http://www.bloomberg.com/professional/contact-menu/?utm_source=bloomberg-menu&amp;utm_medium=bcom&amp;bbgsum=DG-WS-PROF-DEMO-bbgmenu">Bloomberg Terminal Demo Request</a>    </div>
# 		<div id="bb-that--container" class="bb-that__sitemap bb-that--container" tabindex="-1" role="dialog">
#
#     <ul class="bb-that__sitemap-sections bb-that--visible-md bb-that--visible-lg"></ul>
#
#         <ul class="bb-that__sitemap-sections bb-that--visible-sm"></ul>
#
#     <button class="bb-that__close" aria-label="Close" tabindex="0"></button>
# </div>	</nav>
# </div>
# <div id="that-jump-content--default" tabindex="-1"></div>
# <script>(function(){var md="                    &lt;li class=\"bb-that__col bb-that__col--md\"&gt;            &lt;section class=\"bb-that-category\"&gt;    &lt;h3 id=\"that-list--bloomberg--1\" class=\"bb-that-category__title\"&gt;Bloomberg&lt;/h3&gt;&lt;div class=\"bb-that-category__content\"&gt;&lt;p class=\"bb-that-category__text\"&gt;Connecting decision makers to a dynamic network of information, people and ideas, Bloomberg quickly and accurately delivers business and financial information, news and insight around the world.&lt;/p&gt;&lt;/div&gt;&lt;/section&gt;            &lt;section class=\"bb-that-category\"&gt;    &lt;h3 id=\"that-list--for_customers--2\" class=\"bb-that-category__title\"&gt;For Customers&lt;/h3&gt;&lt;ul class=\"bb-that-category__content\" aria-labelledby=\"that-list--for_customers--2\"&gt;&lt;li class=\"bb-that-category__item\"&gt;&lt;a class=\"bb-that-category__link\" href=\"https://bba.bloomberg.net/?utm_source=bloomberg-menu&amp;amp;utm_medium=bcom\" tabindex=\"0\"&gt;Bloomberg Anywhere Remote Login&lt;/a&gt;&lt;/li&gt;&lt;li class=\"bb-that-category__item\"&gt;&lt;a class=\"bb-that-category__link\" href=\"http://www.bloomberg.com/professional/downloads/?utm_source=bloomberg-menu&amp;amp;utm_medium=bcom\" tabindex=\"0\"&gt;Software Updates&lt;/a&gt;&lt;/li&gt;&lt;li class=\"bb-that-category__item\"&gt;&lt;a class=\"bb-that-category__link\" href=\"http://service.bloomberg.com/portal/sessions/new?utm_source=bloomberg-menu&amp;amp;utm_medium=bcom\" tabindex=\"0\"&gt;Manage Products and Account Information&lt;/a&gt;&lt;/li&gt;&lt;/ul&gt;&lt;/section&gt;            &lt;section class=\"bb-that-category\"&gt;    &lt;h3 id=\"that-list--support--3\" class=\"bb-that-category__title\"&gt;Support&lt;/h3&gt;&lt;div class=\"bb-that-category__content\"&gt;&lt;p class=\"bb-that-category__text\"&gt;&lt;span&gt;Americas&lt;/span&gt;+1 212 318 2000&lt;/p&gt;&lt;p class=\"bb-that-category__text\"&gt;&lt;span&gt;EMEA&lt;/span&gt;+44 20 7330 7500&lt;/p&gt;&lt;p class=\"bb-that-category__text\"&gt;&lt;span&gt;Asia Pacific&lt;/span&gt;+65 6212 1000&lt;/p&gt;&lt;/div&gt;&lt;/section&gt;    &lt;/li&gt;                    &lt;li class=\"bb-that__col bb-that__col--md\"&gt;            &lt;section class=\"bb-that-category\"&gt;    &lt;h3 id=\"that-list--company--4\" class=\"bb-that-category__title\"&gt;Company&lt;/h3&gt;&lt;ul class=\"bb-that-category__content\" aria-labelledby=\"that-list--company--4\"&gt;&lt;li class=\"bb-that-category__item\"&gt;&lt;a class=\"bb-that-category__link\" href=\"https://www.bloomberg.com/company/?utm_source=bloomberg-menu&amp;amp;utm_medium=bcom\" tabindex=\"0\"&gt;About&lt;/a&gt;&lt;/li&gt;&lt;li class=\"bb-that-category__item\"&gt;&lt;a class=\"bb-that-category__link\" href=\"https://www.bloomberg.com/company/what-we-do/?utm_source=bloomberg-menu&amp;amp;utm_medium=bcom\" tabindex=\"0\"&gt;Careers&lt;/a&gt;&lt;/li&gt;&lt;li class=\"bb-that-category__item\"&gt;&lt;a class=\"bb-that-category__link\" href=\"https://www.bloomberg.com/company/diversity-inclusion/?utm_source=bloomberg-menu&amp;amp;utm_medium=bcom\" tabindex=\"0\"&gt;Diversity and Inclusion&lt;/a&gt;&lt;/li&gt;&lt;li class=\"bb-that-category__item\"&gt;&lt;a class=\"bb-that-category__link\" href=\"https://www.bloomberg.com/company/innovation/?utm_source=bloomberg-menu&amp;amp;utm_medium=bcom\" tabindex=\"0\"&gt;Innovation&lt;/a&gt;&lt;/li&gt;&lt;li class=\"bb-that-category__item\"&gt;&lt;a class=\"bb-that-category__link\" href=\"https://www.bloomberg.com/company/philanthropy/?utm_source=bloomberg-menu&amp;amp;utm_medium=bcom\" tabindex=\"0\"&gt;Philanthropy&lt;/a&gt;&lt;/li&gt;&lt;li class=\"bb-that-category__item\"&gt;&lt;a class=\"bb-that-category__link\" href=\"https://www.bloomberg.com/company/sustainability/?utm_source=bloomberg-menu&amp;amp;utm_medium=bcom\" tabindex=\"0\"&gt;Sustainability&lt;/a&gt;&lt;/li&gt;&lt;li class=\"bb-that-category__item\"&gt;&lt;a class=\"bb-that-category__link\" href=\"http://www.bloomberg.com/londo ...
#                 <div class="bb-nav-placeholder">
#             <div class="bb-nav-root"> <nav is="bb-nav" class="bb-nav" id="bb-nav" data-theme="default" data-persist-for="index" data-mode="index" data-reg-env="production" data-progress="0" data-headline="" data-base="https://nav.bloomberg.com" data-tracker-category="nav" data-tracker-events="click" data-tracker-label="header" data-site="cojp" data-user-country="US" data-user-region="US"> <div class="bb-nav__container"> <div class="bb-nav__content"> <h1 class="bb-nav-logo" is="bb-nav-logo"> <a href="/" class="bb-nav-logo__link" data-tracker-label="logo" data-tracker-action="click"></a> <span class="bb-nav-logo__arrow"></span> </h1><div class="bb-nav-content-logo" is="bb-nav-content-logo"> <h1 class="bb-nav-content-logo__headline" data-tracker-label="content"> <a href="/" class="bb-nav-content-logo__site" data-tracker-label="logo" data-tracker-action="click"></a> </h1> <div class="bb-nav-content-logo__down-arrow" data-tracker-label="expand" data-tracker-action="click"></div> </div><h2 class="bb-nav-headline"></h2><div class="bb-nav-categories"> <ul class="bb-nav-categories__container"> <li class="bb-nav-categories__home"> <a href="/" class="bb-nav-categories__home-link"> ホームページ </a> </li> <li is="bb-nav-category" class="bb-nav-categories__category  " data-tracker-label="undefined" data-vertical="undefined"> <div class="bb-nav-categories__category-container"> <div class="bb-nav-categories__notch"></div> <a href="/" class="bb-nav-categories__link" data-category-path="/undefined" data-category-vertical="undefined" target="_self" data-tracker-action="click">ニュース</a> </div> </li><li is="bb-nav-category" class="bb-nav-categories__category  " data-tracker-label="undefined" data-vertical="undefined"> <div class="bb-nav-categories__category-container"> <div class="bb-nav-categories__notch"></div> <a href="/markets/stocks" class="bb-nav-categories__link" data-category-path="/undefined" data-category-vertical="undefined" target="_self" data-tracker-action="click">マーケット情報</a> </div> </li><li is="bb-nav-category" class="bb-nav-categories__category  " data-tracker-label="undefined" data-vertical="undefined"> <div class="bb-nav-categories__category-container"> <div class="bb-nav-categories__notch"></div> <a href="/video" class="bb-nav-categories__link" data-category-path="/undefined" data-category-vertical="undefined" target="_self" data-tracker-action="click">ビデオ・TV</a> </div> </li><li is="bb-nav-category" class="bb-nav-categories__category  " data-tracker-label="undefined" data-vertical="undefined"> <div class="bb-nav-categories__category-container"> <div class="bb-nav-categories__notch"></div> <a href="http://about.bloomberg.co.jp" class="bb-nav-categories__link" data-category-path="/undefined" data-category-vertical="undefined" target="_blank" data-tracker-action="click">ブルームバーグについて</a> </div> </li> <li class="bb-nav-categories__category bb-nav-categories__experience"> <bb-experience-select class="bb-nav-mobile-experience-select"></bb-experience-select> </li> </ul> </div><div class="bb-nav-touts" is="bb-nav-touts" data-tracker-label="tout"> <a target="_blank" class="bb-nav-touts__link" href="https://www.bloomberg.com/asia" data-tracker-label="bloomberg_(en)" data-tracker-action="click"> Bloomberg (EN) </a> </div><div class="bb-nav-social-container"> <bb-social class="bb-nav-social"></bb-social> </div><span class="bb-nav-search" is="bb-nav-search"> <gcse:searchbox></gcse:searchbox> </span> <span class="bb-nav-search__icon"></span> </div> </div> <div class="bb-nav-search-results"><gcse:searchresults></gcse:searchresults></div><div class="bb-progress"> <div class="bb-progress__status" style="transform: translateX(0%);-webkit-transform: translateX(0%);-ms-transform: translateX(0%)"></div> </div> </nav> </div>
#         </div>
#                 <div class="breaking-news-placeholder empty" data-region="cojp" data-publishedstate="PUBLISHED"></div>
#                 <div id="skip-to-main-content" style="height: 0; width: 0;"></div>
#     <div id="that-jump-content" style="height: 0; width: 0;"></div>
#                 <main class="hub-main no-breaking" data-path="/lineup/api/cojp/lazy_load/cojp-v2" data-curation-id="cojp-v2" data-published-state="published">
#                     <section class="hub-zone-full" data-zoneid="Header">
#         <section class="hub-zone-full__content">
#         <section class="embed-module" id="data_drawer" data-bound="executed"><div class="thirdparty-embed mod-story" data-id="https://www.bloomberg.co.jp/markets/components/data-drawer?locale=ja&amp;showTabs=true&amp;linksType=tout" data-tracking-type="Curated">
#             <div class="thirdparty-embed__container">
#             <iframe src="https://www.bloomberg.co.jp/markets/components/data-drawer?locale=ja&amp;showTabs=true&amp;linksType=tout" allowfullscreen="true" frameborder="0" scrolling="no" width="100%" height="96px" data-embed-id="https://www.bloomberg.co.jp/markets/components/data-drawer?locale=ja&amp;showTabs=true&amp;linksType=tout"></iframe>
#         </div>
#         </div></section>
#         <script type="module/json" id="module-json-data_drawer">{"id":"data_drawer","theme":"","title":null,"tracking":{"id":"ce1577c8-b741-4f53-8a34-365f49f672d8","title":"Data Drawer"},"variation":"","autofillData":null}</script>
#
#     </section>
#     </section><section class="hub-zone-righty" data-zoneid="Top">
#         <section class="hub-zone-righty__content">
#         <section class="hero-module" data-variation="hfs_two_flex" id="hub_hero_white_version" data-bound="executed"><article class="hero-module__story mod-story" data-id="Q19YZXDWX2PW01" data-tracking-type="Story" data-type="article">
#             <div class="hero-module__logo-links">
#
#         </div>
#         <section class="hero-module__image">
#             <a href="/news/articles/2019-11-20/Q19YZXDWX2PW01?srnd=cojp-v2" class="hero-module__image-link">
#                 <img alt="President Trump Departs White House For Texas" src="https://assets.bwbx.io/images/users/iqjWHBFdfxIU/ih16Vmuv_M2I/v1/840x560.jpg" class="hero-module__image-img" />
#             </a>
#         </section>
#         <div class="hero-module__info ">
#             <a href="/news/articles/2019-11-20/Q19YZXDWX2PW01?srnd=cojp-v2" class="hero-module__headline-link">
#                 【今朝の５本】仕事始めに読んでおきたいニュース
#             </a>
#
#         <div class="hero-module__byline">by 千葉 茂</div>
#
#
#         </div>
#         </article><article class="hero-module__story mod-story" data-id="Q1AGMDT0G1KY01" data-tracking-type="Story" data-updated-at="2019-11-20T23:42:45.676Z" data-type="article">
#             <div class="hero-module__logo-links">
#
#         </div>
#         <section class="hero-module__image">
#             <a href="/news/articles/2019-11-20/Q1AGMDT0G1KY01?srnd=cojp-v2" class="hero-module__image-link">
#                 <img alt="Anti-Government Protests Continue in Hong Kong" src="https://assets.bwbx.io/images/users/iqjWHBFdfxIU/i_pn_20cVjdQ/v1/840x560.jpg" class="hero-module__image-img" />
#             </a>
#         </section>
#         <div class="hero-module__info ">
#             <a href="/news/articles/2019-11-20/Q1AGMDT0G1KY01?srnd=cojp-v2" class="hero-module__headline-link">
#                 米下院、香港人権法案を可決－トランプ大統領は署名の見通し
#             </a>
#
#         <div class="hero-module__byline">by Daniel Flatley、Justin Sink</div>
#
#
#         </div>
#         </article><article class="hero-module__story mod-story" data-id="Q1A8U6DWLU6P01" data-tracking-type="Story" data-updated-at="2019-11-20T21:49:49.991Z" data-type="article">
#             <div class="hero-module__logo-links">
#
#         </div>
#         <section class="hero-module__image">
#             <a href="/news/articles/2019-11-20/Q1A8U6DWLU6P01?srnd=cojp-v2" class="hero-module__image-link">
#                 <img alt="U.S. Stocks Continue Rally Closing Up Over 100 Points" src="https://assets.bwbx.io/images/users/iqjWHBFdfxIU/ifZ0wzPpCn_o/v0/-1x560.jpg" class="hero-module__image-img" />
#             </a>
#         </section>
#         <div class="hero-module__info ">
#             <a href="/news/articles/2019-11-20/Q1A8U6DWLU6P01?srnd=cojp-v2" class="hero-module__headline-link">
# ...
# 50)};a.src=c})(document);</script><script type="text/javascript" async="" src="//consent.trustarc.com/notice?domain=bloomberg-iab.com&amp;c=teconsent&amp;gtm=1&amp;behavior=expressed&amp;text=true"></script>
#
# <script type="text/javascript" id="">(function(){function f(){if(!window.frames.__cmpLocator)if(document.body){var a=document.body,b=document.createElement("iframe");b.style="display:none";b.name="__cmpLocator";b.id="__cmpTrustarc";b.src="//trustarc.mgr.consensu.org/get?name\x3dcmpcookie.html";a.appendChild(b)}else setTimeout(f,5)}function g(){var a=arguments;__cmp.a=__cmp.a||[];if(a.length)if("ping"===a[0])a[2]({gdprAppliesGlobally:e,cmpLoaded:!1},!0);else __cmp.a.push([].slice.apply(a));else return __cmp.a}function d(a){try{var b=
# "string"===typeof a.data,c=b?JSON.parse(a.data):a.data;if(c.__cmpCall){var d=c.__cmpCall;window.__cmp(d.command,d.parameter,function(c,f){var e={__cmpReturn:{returnValue:c,success:f,callId:d.callId}};a.source.postMessage(b?JSON.stringify(e):e,"*")})}}catch(l){}}var h=!0,e=!1;f();"function"!==typeof __cmp&amp;&amp;(window.__cmp=g,__cmp.msgHandler=d,__cmp.gdprApplies=h,__cmp.gdprAppliesGlobally=e,window.addEventListener?window.addEventListener("message",d,!1):window.attachEvent("onmessage",d));var k=setInterval(function(){window.__cmp("getConsentData",
# null,function(a,b){if(b){var c=new Date;c.setTime(c.getTime()+31536E6);c="expires\x3d"+c.toUTCString();document.cookie="euconsent\x3d"+a.consentData+"; "+c;clearInterval(k)}})},250)})();</script><iframe name="__cmpLocator" id="__cmpTrustarc" src="//trustarc.mgr.consensu.org/get?name=cmpcookie.html" style="display: none;"></iframe>
#
# <script type="text/javascript" id="">(function(){var b=document.querySelector("footer.bb-global-footer");if(b)try{var c=b.querySelector(".bb-global-footer__group");var d=c.querySelectorAll(".bb-global-footer__link")[1];var a=document.createElement("div");a.id="teconsent";a.style.display="inline-block";a.classList.add("bb-global-footer__link");c.insertBefore(a,d)}catch(e){console.error(e)}})();</script><script type="text/javascript" id="">(function(b,c,e,f,d){b[d]=b[d]||[];var g=function(){var a={ti:"5820275"};a.q=b[d];b[d]=new UET(a);b[d].push("pageLoad")};var a=c.createElement(e);a.src=f;a.async=1;a.onload=a.onreadystatechange=function(){var b=this.readyState;b&amp;&amp;"loaded"!==b&amp;&amp;"complete"!==b||(g(),a.onload=a.onreadystatechange=null)};c=c.getElementsByTagName(e)[0];c.parentNode.insertBefore(a,c)})(window,document,"script","//bat.bing.com/bat.js","uetq");</script><script type="text/javascript" id="">var DATALAYER_OBJECT_NAME="dataLayer",referrerOverride=function(d){var c=window[DATALAYER_OBJECT_NAME]||[];c.push({event:"optimizely-referrer-override","optimizely-referrer":d})},sendCampaignData=function(d,c,h,g,f,k,b,a,e){optimizely&amp;&amp;"function"===typeof optimizely.get&amp;&amp;(g=optimizely.get("data")&amp;&amp;optimizely.get("data").campaigns[c]&amp;&amp;optimizely.get("data").campaigns[c].integrationSettings&amp;&amp;optimizely.get("data").campaigns[c].integrationSettings.google_universal_analytics&amp;&amp;optimizely.get("data").campaigns[c].integrationSettings.google_universal_analytics.universal_analytics_slot)&amp;&amp;
# (d=d?d+"("+c+")":c,h=h.join(","),f=f?f+"("+k+")":h+"("+k+")",b=b?b+"("+a+")":a,e=e?"holdback":"treatment",e=[d,f,b,e].join(":"),b=window[DATALAYER_OBJECT_NAME]||[],b.push({event:"campaign-decided","optimizely-dimension-value":e,"optimizely-dimension-number":g}))},initNewOptimizelyIntegration=function(d,c){var h=!1,g=function(b){var a=window.optimizely.get&amp;&amp;window.optimizely.get("state"),e=a.getRedirectInfo()&amp;&amp;a.getRedirectInfo().referrer;!h&amp;&amp;e&amp;&amp;(d(e),h=!0);a=a.getCampaignStates({isActive:!0});a=a[b];
# e=a.campaignName;if(0&lt;a.audiences.length){var f=a.audiences.map(function(a){return a.name});var g=a.audiences.map(function(a){return a.id})}else f=["everyone_else"],g=[0];var k=a.experiment.name,l=a.experiment.id,m=a.variation.name,n=a.variation.id;c(e,b,f,g,k,l,m,n,a.isInCampaignHoldback)},f=function(){window.optimizely=window.optimizely||[];window.optimizely.push({type:"addListener",filter:{type:"lifecycle",name:"campaignDecided"},handler:function(b){b=b.data.campaign.id;g(b)}})},k=function(){var b=
# window.optimizely.get&amp;&amp;window.optimizely.get("state");if(b){b=b.getCampaignStates({isActive:!0});for(var a in b)g(a)}};k();f()},initOptimizelyIntegration=function(d,c){window.optimizely&amp;&amp;"function"===typeof window.optimizely.get&amp;&amp;initNewOptimizelyIntegration(d,c)};initOptimizelyIntegration(referrerOverride,sendCampaignData);</script><script type="text/javascript" id="">_linkedin_partner_id="403593";window._linkedin_data_partner_ids=window._linkedin_data_partner_ids||[];window._linkedin_data_partner_ids.push(_linkedin_partner_id);</script><script type="text/javascript" id="">(function(){var b=document.getElementsByTagName("script")[0],a=document.createElement("script");a.type="text/javascript";a.async=!0;a.src="https://snap.licdn.com/li.lms-analytics/insight.min.js";b.parentNode.insertBefore(a,b)})();</script>
# <noscript>
# &lt;img height="1" width="1" style="display:none;" alt="" src="https://dc.ads.linkedin.com/collect/?pid=403593&amp;amp;fmt=gif"&gt;
# </noscript>
# <script type="text/javascript" id="" charset="utf-8" src="//b-code.liadm.com/a-015y.min.js"></script><script type="text/javascript" id="">(function(b,e){b.cmd=b.cmd||[];if(e){var a=e.split(":");a=atob(a[1]);a=JSON.parse(a);a=a.ipc_id;for(var f=1,g=73,c=!1,d=0;d&lt;a.length&amp;&amp;!(c=+a[d],c=c&gt;=f&amp;&amp;c&lt;=g);d++);c&amp;&amp;b.cmd.push(function(){"pubads"in b&amp;&amp;b.pubads().setTargeting("ss","on")})}})(window.googletag||{},google_tag_manager["GTM-MNTH5N"].macro(43));</script>
#
# <script type="text/javascript" id="" src="https://ads.avocet.io/s?add=5adf6ad75f7614a66abb437a&amp;ty=j"></script><script type="text/javascript" id="">function cb(a){dataLayer.push({"Private Browser":a})}function isChrome(){return!!("undefined"!==typeof window&amp;&amp;window.navigator&amp;&amp;window.navigator.userAgent&amp;&amp;/Chrome/.test(window.navigator.userAgent)&amp;&amp;window.navigator.vendor&amp;&amp;/Google Inc/.test(window.navigator.vendor))}function isSafari(){return!(!("undefined"!==typeof window&amp;&amp;window.navigator&amp;&amp;window.navigator.userAgent&amp;&amp;/Safari/i.test(window.navigator.userAgent))||/Chrome/i.test(window.navigator.userAgent))}
# function isIEorEdge(){return!("undefined"===typeof window||!window.PointerEvent&amp;&amp;!window.MSPointerEvent)}function isFirefox(){return!!("undefined"!==typeof document&amp;&amp;document.documentElement&amp;&amp;document.documentElement.style&amp;&amp;"MozAppearance"in document.documentElement.style)}function retry(a,c){var e=0,f=50,b=!1,d=window.setInterval(function(){a()&amp;&amp;(window.clearInterval(d),c(b));e++&gt;f&amp;&amp;(window.clearInterval(d),b=!0,c(b))},10)}
# if(isChrome())navigator&amp;&amp;navigator.storage&amp;&amp;navigator.storage.estimate?navigator.storage.estimate().then(function(a){12E7&gt;a.quota?cb(!0):cb(!1)}):cb(!1);else if(isSafari())try{window.openDatabase(null,null,null,null),cb(!1)}catch(a){cb(!0)}else if(isFirefox()){var db;try{db=window.indexedDB.open("test")}catch(a){is_private=!0}"undefined"===typeof is_private&amp;&amp;retry(function(){return"done"===db.readyState?cb(!0):cb(!1)},function(a){a||(is_private=db.result?cb(!1):cb(!0))})}else if(isIEorEdge()){try{if(!window.indexedDB)throw Error("private mode");
# }catch(a){cb(!0)}cb(!1)}cb(!1);</script>
# <script type="text/javascript" id="">window._tfa=window._tfa||[];window._tfa.push({notify:"event",name:"page_view",id:1194877});!function(a,b,d,c){document.getElementById(c)||(a.async=1,a.src=d,a.id=c,b.parentNode.insertBefore(a,b))}(document.createElement("script"),document.getElementsByTagName("script")[0],"//cdn.taboola.com/libtrc/unip/1194877/tfa.js","tb_tfa_script");</script>
# <noscript>
#   &lt;img src="//trc.taboola.com/1194877/log/3/unip?en=page_view" width="0" height="0" style="display:none" alt=""&gt;
# </noscript>
#
# <script type="text/javascript" id="">!function(b,a,c,d,e){if(!a)for(a=a||{},window.permutive=a,a.q=[],a.config=e||{},a.config.projectId=c,a.config.apiKey=d,a.config.environment=a.config.environment||"production",b="addon identify track trigger query segment segments ready on once user consent".split(" "),c=0;c&lt;b.length;c++)d=b[c],a[d]=function(b){return function(){var c=Array.prototype.slice.call(arguments,0);a.q.push({functionName:b,arguments:c})}}(d)}(document,window.permutive,"b05a4917-e163-4223-8738-c83650d2b6a3","6c1e898a-361a-40db-9558-0ceedd3d9a3f",
# {});window.googletag=window.googletag||{};window.googletag.cmd=window.googletag.cmd||[];window.googletag.cmd.push(function(){if(0===window.googletag.pubads().getTargeting("permutive").length){var b=window.localStorage.getItem("_pdfps");window.googletag.pubads().setTargeting("permutive",b?JSON.parse(b):[])}});permutive.addon("web",{page:{adcode:"japan\/home"}});</script>
#     <script type="text/javascript" id="" src="https://cdn.permutive.com/b05a4917-e163-4223-8738-c83650d2b6a3-web.js"></script><script async="true" src="//cdn.adsafeprotected.com/iasPET.1.js"></script><script async="true" src="https://z.moatads.com/bloombergprebidheader853620778109/moatheader.js"></script><div style="width:0px; height:0px; display:none; visibility:hidden;" id="batBeacon0.4301035533612665"><img style="width:0px; height:0px; display:none; visibility:hidden;" id="batBeacon0.7906495894896597" width="0" height="0" alt="" src="https://bat.bing.com/action/0?ti=5820275&amp;Ver=2&amp;mid=cb0d6520-ed38-8d34-9121-433ca918dcc9&amp;pi=1200101525&amp;lg=ja&amp;sw=1920&amp;sh=1080&amp;sc=24&amp;tl=Bloomberg.co.jp&amp;p=https%3A%2F%2Fwww.bloomberg.co.jp%2F&amp;r=&amp;lt=8403&amp;evt=pageLoad&amp;msclkid=N&amp;rn=525939" /></div><script async="async" type="text/javascript" crossorigin="" src="//trustarc.mgr.consensu.org/get?name=cmp.js"></script><script type="text/javascript" src="https://mb.moatads.com/yi.js?ud=0&amp;qn=%604%7BZEYwoqI%24%5BK%2BdLLU)%2CMm~tM!90vv9L%24%2FoDb%2Fz(lKm3GFlNUU%2Cu%5Bh_GcS%25%5BHvLU%5B4(K%2B%7BgeFWl_%3DNqUXR%3A%3D%2BAxMn%3Ch%2CyenA8p%2FHm%24%60%233P(ry5*ZRocMp1tq%5BN%7Bq%60RP%3CG.ceFW%7CoG%22mxT%3Bwv%40V374BKm55%3D%261fp%5BoU5t)3_%3C%3Ce%23Vp!%24Pjr%3AGe31k5X%5BG%5E%5B)%2C2iVSX%3C_Y%7B!7IQ3HbmUZzCFm%5Du!x2l.uBlTVU%2F.%3Dh%3Ft%40yUtKC&amp;qp=10000&amp;is=&amp;iv=7&amp;qt=0&amp;gz=1&amp;hh=0&amp;hn=0&amp;tw=null&amp;qc=10&amp;qd=10&amp;qf=929&amp;qe=888&amp;qh=945&amp;qg=1020&amp;qm=-540&amp;qa=1920&amp;qb=1080&amp;qi=1920&amp;qj=1040&amp;po=1-0020002000002120&amp;vy=ot%24b%5Bh%40%22oDgO%3DLlE6%3Avy%2CUitwbYF%3EeRy6%3A0%3FeS%22%5Bby%3Fa0CB%23J%3B%2Bt.Nm!_vVM%24Y7%2561oA%3CuJ%3BO*zDRd%40IU%5B.%22%24b_o%3FtVD%5D%5BpN%7CQF%40Sy7%7BA&amp;qr=0&amp;url=https%3A%2F%2Fwww.bloomberg.co.jp%2F&amp;confidence=2&amp;pcode=bloombergprebidheader853620778109&amp;callback=MoatNadoAllJsonpRequest_52154879"></script><script type="text/javascript" src="https://geo.moatads.com/n.js?e=35&amp;ud=0&amp;qn=%604%7BZEYwoqI%24%5BK%2BdLLU)%2CMm~tM!90vv9L%24%2FoDb%2Fz(lKm3GFlNUU%2Cu%5Bh_GcS%25%5BHvLU%5B4(K%2B%7BgeFWl_%3DNqUXR%3A%3D%2BAxMn%3Ch%2CyenA8p%2FHm%24%60%233P(ry5*ZRocMp1tq%5BN%7Bq%60RP%3CG.ceFW%7CoG%22mxT%3Bwv%40V374BKm55%3D%261fp%5BoU5t)3_%3C%3Ce%23Vp!%24Pjr%3AGe31k5X%5BG%5E%5B)%2C2iVSX%3C_Y%7B!7IQ3HbmUZzCFm%5Du!x2l.uBlTVU%2F.%3Dh%3Ft%40yUtKC&amp;qp=10000&amp;is=&amp;iv=7&amp;qt=0&amp;gz=1&amp;hh=0&amp;hn=0&amp;tw=null&amp;qc=10&amp;qd=10&amp;qf=929&amp;qe=888&amp;qh=945&amp;qg=1020&amp;qm=-540&amp;qa=1920&amp;qb=1080&amp;qi=1920&amp;qj=1040&amp;po=1-0020002000002120&amp;vy=ot%24b%5Bh%40%22oDgO%3DLlE6%3Avy%2CUitwbYF%3EeRy6%3A0%3FeS%22%5Bby%3Fa0CB%23J%3B%2Bt.Nm!_vVM%24Y7%2561oA%3CuJ%3BO*zDRd%40IU%5B.%22%24b_o%3FtVD%5D%5BpN%7CQF%40Sy7%7BA&amp;qr=0&amp;url=https%3A%2F%2Fwww.bloomberg.co.jp%2F&amp;confidence=2&amp;pcode=bloombergprebidheader853620778109&amp;ql=%3B%5BpwxnRd%7Dt%3Aal9EU%22y%2F.D%5B5%2F%5BGI%3Fi6%5EB61%2F%3DSqcMr1%7B%2CTu9LJJ(a.P%2B)s1(uA&amp;qo=0&amp;i=BLOOMBERG_PREBID_HEADER1&amp;hp=1&amp;wf=1&amp;kq=1&amp;hq=0&amp;hs=0&amp;hu=0&amp;hr=0&amp;ht=1&amp;dnt=0&amp;bq=11&amp;f=0&amp;j=&amp;t=1574296903710&amp;de=80115577231&amp;rx=544216133541&amp;m=0&amp;ar=c3c67b6-clean&amp;q=1&amp;cb=0&amp;cu=1574296903710&amp;ll=2&amp;lm=0&amp;ln=0&amp;em=0&amp;en=0&amp;d=undefined%3Aundefined%3Aundefined%3Aundefined&amp;zMoatAdUnit1=-&amp;zMoa ...
# <iframe src="//i.liadm.com/s/c/a-015y?s=&amp;cim=&amp;ps=true&amp;ls=true&amp;duid=a-015y--4b7861e0-23b7-47d2-9c69-bacbc3fdd675&amp;domainSessionId=&amp;ppid=0&amp;euns=0&amp;ci=0&amp;version=sc-2.2.2&amp;nosync=true&amp;" style="display: none; width: 0px; height: 0px; border: 0px;"></iframe>
# <script type="text/javascript" src="https://mb.moatads.com/s.js?url=https%3A%2F%2Fwww.bloomberg.co.jp%2F&amp;confidence=2&amp;pcode=bloombergdfpcw4670778881&amp;callback=BrandSafetyNadoscallback_23126881"></script><iframe id="google_osd_static_frame_4866623526861" name="google_osd_static_frame" style="display: none; width: 0px; height: 0px;"></iframe><iframe id="LOTCCFrame_1574296906841" src="https://bcp.crwdcntrl.net/5/c=12107/rand=570635689/pv=y/cmp=1/cmpto=250/int=%23OpR%2380088%23Total%20Site%20Traffic%20%3A%20https%3A%2F%2Fwww.bloomberg.co.jp/int=%23OpR%2381954%23dataLayer%20%3A%20adcode%20%3A%20japan%2Fhome/int=%23OpR%2381967%23dataLayer%20%3A%20brand%20%3A%20business/int=%23OpR%2381968%23dataLayer%20%3A%20contentType%20%3A%20homepage-cojpv2/int=%23OpR%2381970%23dataLayer%20%3A%20pageType%20%3A%20homepage/int=%23OpR%2381971%23dataLayer%20%3A%20refresh%20%3A%20false/int=%23OpR%2381976%23dataLayer%20%3A%20transporter%20%3A%20false/rt=ifr" title="empty" tabindex="-1" role="presentation" aria-hidden="true" style="border: 0px; width: 0px; height: 0px; display: block;"></iframe><script type="text/javascript" id="">(function(a,b,c){var e=decodeURIComponent;var d="||";var g=";;",f="split",h="length",m="indexOf",k="localStorage",l="_ccmdt";a[c]=a[c]||{};a[c].us={};b=a[k]?a[k][l]||"":(b=b.cookie.match(l+"\x3d([^;]*)"))&amp;&amp;b[1]||"";e=e(b)[f](d);b=e[h];if(0&lt;b)for(;b--;)d=e[b][f]("\x3d"),1&lt;d[h]&amp;&amp;(-1&lt;d[1][m](g)?(a[c].us[d[0]]=d[1][f](g),a[c].us[d[0]].pop()):a[c].us[d[0]]=d[1])})(window,document,"_ml");
# function tagWrapper(a){var b=google_tag_manager["GTM-MNTH5N"].macro(51)||"";a=a||"";a=b+"|"+a;"|"===a&amp;&amp;(a=null);var c=window;b="script";c._ml=c._ml||{};c._ml.eid="50066";c._ml.fp=a;c._ml.informer={enable:!0};a=document.getElementsByTagName(b)[0];c=new Date;b=document.createElement(b);b.async=1;b.src="https://ml314.com/tag.aspx?"+c.getDate()+c.getMonth();a.parentNode.insertBefore(b,a)}"undefined"!==typeof ga&amp;&amp;(ga("create",google_tag_manager["GTM-MNTH5N"].macro(52),"auto"),ga(function(a){tagWrapper(a.get("clientId"))}));</script><img src="//bcp.crwdcntrl.net/map/c=12392/tp=BLPI/tpid=undefined" alt="" /></body></html>

# %%
type(html)
# Out:
# bytes
